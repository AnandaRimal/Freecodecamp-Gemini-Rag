# %%
from google import genai
from google.genai import types
import time

# %%
client = genai.Client()

# %%
# Upload the file using the Files API, supply a file name which will be visible in citations
sample_file = client.files.upload(file='microprocessor_book.pdf', config={'name': 'microprocessorbook'})

# %%
# Create the File Search store with an optional display name
file_search_store = client.file_search_stores.create(config={'display_name': 'book2'})

# %%
# Import the file into the File Search store
operation = client.file_search_stores.import_file(
    file_search_store_name=file_search_store.name,
    file_name=sample_file.name
)

# %%
# Wait until import is complete
while not operation.done:
    time.sleep(5)
    operation = client.operations.get(operation)

# %%
# Ask a question about the file
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="""Cwhats the book is about""",
    config=types.GenerateContentConfig(
        tools=[
            types.Tool(
                file_search=types.FileSearch(
                    file_search_store_names=[file_search_store.name]
                )
            )
        ]
    )
)

# %%
print(response.text)
print(response.candidates[0].grounding_metadata)
# Out:
# The book, titled "microprocessorbook," is a comprehensive guide to microprocessors, covering their fundamental concepts, architecture, programming, and advanced topics.
#
# Specifically, it delves into:
# *   **Introduction to Microprocessors**: This includes the definition and application areas of microprocessors, the evolution of microprocessor technology, Von Neumann and Harvard Architectures, the Intel Series evolution, and the basic components of a microprocessor-based system like the Arithmetic and Logic Unit (ALU), Control Unit (CU), Registers, Memory, Input/Output, and System Bus.
# *   **Basic Computer Architecture**: The book details the architecture and operations of 8085 and 8086 microprocessors, including their PIN configurations, interrupt handling, addressing modes, memory organization, and concepts like pipelining.
# ...
