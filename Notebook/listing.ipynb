# %%
from google import genai
from google.genai import types
import time

# %%
client = genai.Client()

# %%
## List all files uploaded to the general File API
print('My uploaded files:')
for file in client.files.list():
    print(f"Name: {file.name}, Display Name: {file.display_name}, Size: {file.size_bytes} bytes")
# Out:
# My uploaded files:
# Name: files/storyharry, Display Name: None, Size: 3322916 bytes
# Name: files/hljxtsbnwe9h, Display Name: storyharry, Size: 3322916 bytes

# %%
client.files.delete(name='files/microprocessorbook')
# Out:
# DeleteFileResponse(
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   )
# )

# %%
# List all your File Search stores
for file_search_store in client.file_search_stores.list():
    print(file_search_store)
# Out:
# name='fileSearchStores/teststore-buz9zs7s2lis' display_name='TestStore' create_time=datetime.datetime(2025, 11, 29, 17, 26, 9, 11802, tzinfo=TzInfo(0)) update_time=datetime.datetime(2025, 11, 29, 17, 26, 9, 11802, tzinfo=TzInfo(0)) active_documents_count=2 pending_documents_count=None failed_documents_count=None size_bytes=126
# name='fileSearchStores/business-store-a75k2c1tctcf' display_name='Business Store' create_time=datetime.datetime(2025, 11, 30, 9, 20, 44, 193868, tzinfo=TzInfo(0)) update_time=datetime.datetime(2025, 11, 30, 9, 20, 44, 193868, tzinfo=TzInfo(0)) active_documents_count=5 pending_documents_count=None failed_documents_count=None size_bytes=15066305
# name='fileSearchStores/science-store-zlw0iqegbp9g' display_name='Science Store' create_time=datetime.datetime(2025, 11, 30, 9, 20, 45, 194875, tzinfo=TzInfo(0)) update_time=datetime.datetime(2025, 11, 30, 9, 20, 45, 194875, tzinfo=TzInfo(0)) active_documents_count=5 pending_documents_count=None failed_documents_count=None size_bytes=7868595
# name='fileSearchStores/story-store-tnwlwjuyvbay' display_name='Story Store' create_time=datetime.datetime(2025, 11, 30, 9, 20, 46, 212173, tzinfo=TzInfo(0)) update_time=datetime.datetime(2025, 11, 30, 9, 20, 46, 212173, tzinfo=TzInfo(0)) active_documents_count=5 pending_documents_count=None failed_documents_count=None size_bytes=16614580
# name='fileSearchStores/book2-50ex31pymguw' display_name='book2' create_time=datetime.datetime(2025, 11, 30, 13, 6, 11, 718240, tzinfo=TzInfo(0)) update_time=datetime.datetime(2025, 11, 30, 13, 6, 11, 718240, tzinfo=TzInfo(0)) active_documents_count=1 pending_documents_count=None failed_documents_count=None size_bytes=67871357
# name='fileSearchStores/book2-asl1589wj3vx' display_name='book2' create_time=datetime.datetime(2025, 12, 2, 16, 37, 26, 565147, tzinfo=TzInfo(0)) update_time=datetime.datetime(2025, 12, 2, 16, 37, 26, 565147, tzinfo=TzInfo(0)) active_documents_count=1 pending_documents_count=None failed_documents_count=None size_bytes=67871357

# %%
#delete file search store
client.file_search_stores.delete(name='fileSearchStores/sciencestore-3o2vr5hgl1t8', config={'force': True})
